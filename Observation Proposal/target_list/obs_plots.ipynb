# %%
import numpy as np 
import matplotlib.pyplot as plt

# plt.rcParams["figure.dpi"] = 100
plt.rc('font', family = 'serif', serif = 'cmr10') 
plt.rcParams.update({# Use mathtext, not LaTeX
                            'text.usetex': False,
                            # Use the Computer modern font
                            'font.family': 'serif',
                            'font.serif': 'cmr10',
                            'mathtext.fontset': 'cm',
                            })
plt.rcParams.update({'font.size': 22})
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
colour_arrays = ['red', 'blue', 'green', 'crimson', 'lime']

# %%
V = np.loadtxt('trgt.txt', usecols=(2,), skiprows = 10, unpack=True)
B = V
# print(V.min(), V.max())
# print(B.min(), B.max())
print(B.mean() - 2*B.std(), B.mean() + 2*B.std())

plt.figure(figsize=(12,8))
plt.hist(B, density=False, bins=50, facecolor = 'none', edgecolor = 'k')  # density=False would make counts
plt.ylabel('Stars')
plt.xlabel('Magnitude')
# Out:
# 14.75634010486293 21.33579824599485
# Text(0.5, 0, 'Magnitude')
